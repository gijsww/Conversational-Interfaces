# %%
from requests import get
from bs4 import BeautifulSoup
import re

# %%
def retrieve_data(question_list, answer_list, url, heading_list):
    """function retrieves questions and answers from the RUG FAQ except Immigration"""
    prev_question = ""
    response = get(url)
    html_soup = BeautifulSoup(response.text, 'html.parser')
    data = html_soup.findAll('div',{'class':'rug-clearfix rug-theme--content rug-mb'})
    main_page = html_soup.findAll('div',{'class':'rug-list--accordion__item__header js--togglable-switch'})
    
    for links, headers in zip(data, main_page):
        link = links.findAll('a')
        header = headers.text
        header = header.strip()
        
        if header in heading_list: #exceptions for some pages
            question = header
            question = question_processing(question)   
            answer_links = link
            final_links = link_processing(answer_links)
            answer = clean_answer(links.text)
            answer_list.append([answer,final_links])
            question_list.append(question)
        
        else:
            for a in link:
                if a['href'][0] == "?": #check if link is an internal one
                    current_url = 'https://www.rug.nl/education/faq/'+a['href']          
                    response = get(current_url)
                    html_soup = BeautifulSoup(response.text, 'html.parser')
                    questions = html_soup.find_all(['h2'])
                    content = html_soup.findAll('div',{'class':'rug-clearfix rug-theme--content rug-mb'})
                    s_content = html_soup.find('div',{'class':'rug-clearfix rug-theme--content rug-mb'})
                    overzicht_url.append(current_url)
                    
                    if len(content) == len(questions): #check structure of current questions and answers
                        for question, answer in zip(questions, content):
                            if question.text in heading_list: #check if question contains sub questions
                                links = answer.find_all('a')

                                for a in links: # access the subquestions
                                    question = a.text
                                    question = question_processing(question)
                                    
                                    if a['href'][0] == "?":
                                        current_url = 'https://www.rug.nl/education/faq/'+a['href']
                                        overzicht_url.append(current_url)
                                        response = get(current_url)
                                        html_soup = BeautifulSoup(response.text, 'html.parser')
                                        ans = html_soup.find('div',{'class':'rug-clearfix rug-theme--content rug-mb'})
                                    
                                    elif a['href'][0] == "/":
                                        current_url = 'https://www.rug.nl'+a['href']
                                        overzicht_url.append(current_url)
                                        response = get(current_url)
                                        html_soup = BeautifulSoup(response.text, 'html.parser')
                                        ans = html_soup.find('div',{'class':'rug-clearfix rug-theme--content rug-mb'})
                                    
                                    else: 
                                        current_url = a['href']
                                        overzicht_url.append(current_url)
                                        response = get(current_url)
                                        html_soup = BeautifulSoup(response.text, 'html.parser')
                                        ans = html_soup.find('div',{'class':'rug-clearfix rug-theme--content rug-mb'})

                                    try: #catch errors when external page is formatted differently
                                        answer_links = ans.find_all('a')
                                        final_links = link_processing(answer_links)
                                        answer = clean_answer(ans.text)
                                        answer_list.append([answer,final_links])
                                        question_list.append(question)

                                    except(AttributeError, KeyError) as error: #Structure of external url is different
                                        ans = html_soup.find(['p'])
                                        answer_links = ans.find_all('a')
                                        final_links = link_processing(answer_links)
                                        answer = clean_answer(ans.text)
                                        answer_list.append([answer,final_links])
                                        question_list.append(question)

                            else:
                                question = question_processing(question.text)
                                answer_links = answer.find_all('a')
                                final_links = link_processing(answer_links)
                                answer = clean_answer(answer.text)
                                answer_list.append([answer,final_links])
                                question_list.append(question)

                    else:
                        question = html_soup.find(['h1'])
                        question = question_processing(question.text)
                        if prev_question == question: #no duplicate questions
                            pass
                        
                        else:
                            answer_links = s_content.find_all('a')
                            final_links = link_processing(answer_links)
                            answer = clean_answer(s_content.text)
                            question_list.append(question)
                            answer_list.append([answer,final_links])
                            prev_question = question

                elif a['href'][0] == '/':
                    current_url = 'https://www.rug.nl'+a['href']
                    overzicht_url.append(current_url)
                    response = get(current_url)
                    html_soup = BeautifulSoup(response.text, 'html.parser')
                    ans = html_soup.find('div',{'class':'rug-clearfix rug-theme--content rug-mb'})
                    question = a.text
                    question = question_processing(question)

                    try:               
                        answer_links = ans.find_all('a')
                        final_links = link_processing(answer_links)
                        answer = clean_answer(ans.text)
                        answer_list.append([answer,final_links])
                        question_list.append(question)

                    except(AttributeError, KeyError) as error: #Structure of external url is different
                        ans = html_soup.find(['p'])
                        answer_links = ans.find_all('a')
                        final_links = link_processing(answer_links)
                        answer = clean_answer(ans.text)
                        answer_list.append([answer,final_links])
                        question_list.append(question)

                elif a['href'][0] == 'h':
                    question = a.text
                    question = question_processing(question)
                    final_links = []
                    current_url = a['href']
                    overzicht_url.append(current_url)
                    response = get(current_url)
                    html_soup = BeautifulSoup(response.text, 'html.parser')
                    ans = html_soup.find('div',{'class':'rug-clearfix rug-theme--content rug-mb'})

                    if ans == None:
                        answer = "Alleen een link gevonden"
                        final_links.append(a['href'])
                        answer_list.append([answer,final_links])
                        question_list.append(question)
                    
                    else:
                        answer_links = ans.find_all('a')
                        final_links = link_processing(answer_links)
                        answer = clean_answer(ans.text)                     
                        answer_list.append([answer,final_links])
                        question_list.append(question)

                else:
                    question = headers.text
                    answer_links = links.find_all('a')
                    final_links = link_processing(answer_links)
                    answer = clean_answer(links.text)
                    question = question_processing(question)
                    question_list.append(question)
                    answer_list.append([answer,final_links])
        
    return question_list, answer_list

# %%
def clean_links(link_list):
    '''function that cleans links depending on their target location'''
    clean_links = []
    for link in link_list:
        if link == None: # no link in answer
            clean_links.append(None)
            pass
        
        else:
            link = link['href']
            if link[0] == '?': # target is sub page of the faq
                f_link = 'https://www.rug.nl/education/faq/' + link
                clean_links.append(f_link)
            
            elif link[0] == '/': # target is sub page of the rug site
                f_link = 'https://www.rug.nl' + link
                clean_links.append(f_link)
            
            else: # target is a different link
                clean_links.append(link)

    return clean_links

# %%
def clean_answer(input_text):
    '''function that cleans the answer texts'''
    
    end = "Stel je vraag"
    answer = input_text.strip('\n')
    answer = answer.replace('\n',' ')
    answer = answer.replace('&nbsp;', ' ')
    answer = answer.replace('\xa0', ' ')
    honours = "Heb je nog vragen? Neem contact op met het Honours College via honours rug.nl."
    answer = answer.replace(honours, '')
    
    if answer.endswith(end):
        answer = answer.replace(end,'')
    return answer

# %%
def link_processing(answer_links):
    '''function that processes zero or more links in an answer'''
    for link in answer_links:
        if link.text == 'Stel je vraag':
            answer_links.remove(link)
    final_links = clean_links(answer_links)
    return final_links

# %%
def question_processing(question):
    '''function that removes question marks from questions'''
    question = question.replace('?', '')
    return question

# %%
def button_creation(link):
    '''function that creates aiml buttons for links'''
    
    button = '\n'+ '<button>' + '\n' + '<text>' + '\n'+ 'Klik hier' + '\n' + '</text>' + '\n' + '<url>'+ '\n' +link+ '\n' + '</url>' + '\n' + '</button>'
    return button

# %%
def write_aiml_file(question_list, answer_list):
    '''function that automatically generates aiml file from questions, answers and links in answers'''
    
    with open('aiml_base.aiml', 'w') as f:
        for vraag, antwoord in zip(question_list, answer_list):
            buttons = ""
            if len(antwoord[1]) > 0: #answer contains one or more links; buttons have to be created
                for link in antwoord[1]:
                    buttons += button_creation(link)
                
                f.write('<category>'+'\n'+ '<pattern>'+ '\n'+ vraag+ '\n'+ '</pattern>'+'\n'+
                '<template>'+ '\n'+ antwoord[0] + buttons + '\n' '</template>'+'\n'+'</category>'+'\n'+'\n')
                
            else:
                f.write('<category>'+'\n'+ '<pattern>'+ '\n'+ vraag+ '\n'+ '</pattern>'+'\n'+
                '<template>'+ '\n'+ antwoord[0]+ '\n'+ '</template>'+'\n'+ '</category>'+'\n' + '\n')
    f.close()

# %%
# all pages from the FAQ except immigration
url_list = ['https://www.rug.nl/education/faq/?tcid=verint_3_7394_7394',
            'https://www.rug.nl/education/faq/?tcid=verint_3_7395_7395',
            'https://www.rug.nl/education/faq/?tcid=verint_3_7412_7412', 
            'https://www.rug.nl/education/faq/?tcid=verint_3_7398_7398', 
            'https://www.rug.nl/education/faq/?tcid=verint_3_7399_7399',
            'https://www.rug.nl/education/faq/?tcid=verint_3_7400_7400',
            'https://www.rug.nl/education/faq/?tcid=verint_3_7402_7402', 
            'https://www.rug.nl/education/faq/?tcid=verint_3_7401_7401']


#complete list of headings for exceptions in the site structure
heading_list = ["Introductieperiode", "Vakken, tentamens, boeken", "Aanmelding- en selectieprocedure", 
                "Onderwijs - honoursprogramma", "Ik sta voor meerdere opleidingen ingeschreven", 
                "Ik schrijf me tijdens het studiejaar in", "Aanmelding- en selectieprocedure", 
                "Ik heb nog geen Studielinkaccount","Ik heb al een Studielinkaccount","Onderwijs - honoursprogramma",
                "Aanmaken RUG-account", "Blokkeren RUG-account", "Opheffen RUG-account", "Veiligheid en toezicht tijdens de introductieperiode",
                "Onderwijs- en examenregelingen (OER)","Studentenstatuut","Klachten, bezwaar en beroep", 
                "Vertrouwenspersoon en studentendecaan", "Meer informatie rechtspositie ...", 
                "Aanvragen verklaring (door organisatie)","Career Services", "Aanmelden numerus fixusopleiding", 
                "Selectiepogingen", "Uitslag en bewijs van toelating", "VWO vooropleiding","HBO vooropleiding (bachelor en propedeuse)", 
                "Buitenlandse vooropleiding", "Andere vooropleiding", "Universitaire bachelor"]

# %%
question_list = []
answer_list = []
overzicht_url = []

for url in url_list:
    question_list, answer_list, = retrieve_data(question_list, answer_list, url, heading_list)

print(len(question_list),len(answer_list))
# Out:
# 402 402

# %%
print(len(overzicht_url))
print(overzicht_url)

# %%
write_aiml_file(question_list, answer_list)

# %%
#inspect questions and answers
for vraag, antwoord in zip(question_list, answer_list):
    print(vraag,antwoord,'\n')
# Out:
# Wat is het verschil tussen aanmelden en inschrijven ["Aanmelden en inschrijven zijn twee verschillende acties. Je meldt je via Studielink aan voor een opleiding. Je wordt pas ingeschreven als je alle stappen van de inschrijfprocedure hebt doorlopen.  Informatie over de inschrijfprocedures voor Nederlandse studenten vind je op de onderstaande pagina's op onze website:   Bachelor aanmelding en inschrijving   Master aanmelding en inschrijving      ", ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/', 'https://www.rug.nl/education/master/nederlandse-studenten/aanmelding-en-inschrijving/']]
#
# Hoe meld ik me aan voor een bacheloropleiding ['Informatie over de inschrijfprocedure voor Nederlandse studenten vind je op de pagina Inschrijfprocedure bacheloropleiding op onze website.  Informatie over de inschrijfprocedure voor internationale studenten en Nederlandse studenten met een buitenlandse vooropleiding vind je op de pagina Admissions guide op onze website.    ', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/inschrijfprocedure-bacheloropleiding', 'https://www.rug.nl/education/bachelor/international-students/admission-and-application/application-admission-procedure/']]
#
# Hoe meld ik me aan voor een masteropleiding ['Informatie over de inschrijfprocedure voor Nederlandse studenten vind je op de pagina Inschrijfprocedure masteropleiding op onze website.  Informatie over de inschrijfprocedure voor internationale studenten en Nederlandse studenten met een buitenlandse vooropleiding vind je op de pagina Admissions guide op onze website.    ', ['https://www.rug.nl/education/master/nederlandse-studenten/aanmelding-en-inschrijving/inschrijfprocedure-masteropleiding', 'https://www.rug.nl/education/master/international-students/admission-and-application/application-admission-procedure/']]
#
# Ik heb me aangemeld via Studielink. Wat moet ik nu doen ["In de verschillende inschrijfprocedures staat uitgelegd welke handelingen je nog moet verrichten nadat je je hebt aangemeld via Studielink.  De inschrijfprocedures voor Nederlandse studenten vind je op de onderstaande pagina 's op onze website:   Bachelor aanmelding en inschrijving   Master aanmelding en inschrijving      ", ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/', 'https://www.rug.nl/education/master/nederlandse-studenten/aanmelding-en-inschrijving/']]
#
# Wat moet ik doen als mijn persoonsgegevens volgens Studielink niet gecontroleerd kunnen worden ['Je persoonsgegevens kunnen niet gecontroleerd worden als je geen Nederlandse adres hebt of niet bent ingeschreven in de Basisregistratie Personen (BRP) op het door jou aangegeven adres.    Afhankelijk van je nationaliteit moet je het volgende doen:     Nederlandse nationaliteit: Stuur een kopie van je geldige paspoort of ID-kaart naar:   Rijksuniversiteit Groningen t.a.v. afdeling Studenten Informatie en Administratie Postbus 72 9700 AB Groningen     Internationale studenten Stuur een gewaarmerkte kopie van je geldige paspoort of ID-kaart naar de Bachelor Admissions Office of de Master Admissions Office.     ', ['https://www.rug.nl/education/bachelor/international-students/admission-and-application/application-admission-procedure/contact-the-admissions-office', 'https://www.rug.nl/education/master/international-students/admission-and-application/application-admission-procedure/support/contact-admissions-office']]
#
# Wat moet ik doen als er iets mis gaat met mijn aanmelding via Studielink ['Neem contact op met de Centrale Studenten Administratie.    ', ['https://www.rug.nl/csa']]
#
# Welke opleidingen geven rechtstreeks toelating tot de universiteit ['Diploma’s die rechtstreeks toelating geven zijn:   een vwo-diploma; oude stijl hbs- of gymnasiumdiploma; een propedeuse getuigschrift van de meeste hbo-instellingen in Nederland; een propedeuse getuigschrift van de meeste instellingen voor wetenschappelijk onderwijs in Nederland en van de Open Universiteit; een hbo-diploma van de meeste instellingen voor Hoger Beroeps Onderwijs in Nederland; einddiploma’s van wetenschappelijk onderwijs en de Open Universiteit.   Let op! Sommige bachelopleidingen stellen aanvullende eisen in de vorm van vwo-pakketeisen.    ', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/toelatingseisen/vwo-diploma']]
#
# Ben ik met een vwo-diploma toelaatbaar tot een bacheloropleiding ['Ja, je bent met een vwo-diploma in principe toelaatbaar tot een bacheloropleiding aan de universiteit. Sommige opleidingen stellen wel specifieke eisen aan je profiel en aanvullende vakken.  Meer informatie vind je op de pagina VWO-diploma op onze website.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/toelatingseisen/vwo-diploma']]
#
# Ben ik met een vwo-diploma oude stijl toelaatbaar tot een bacheloropleiding ['Ja, je bent met een vwo-diploma oude stijl in principe toelaatbaar tot een bacheloropleiding aan de universiteit. Sommige opleidingen stellen aanvullende ingangseisen c.q. profieleisen.   Meer informatie over aanvullende ingangseisen vind je op de pagina VWO-diploma op onze website of je neemt contact op met de studieadviseur van de betreffende opleiding.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/toelatingseisen/vwo-diploma', 'https://www.rug.nl/education/contact/study-advisors/']]
#
# Wat kan ik doen als mijn profiel niet toereikend is voor de opleiding van mijn voorkeur ['Neem contact op met de studieadviseur van de betreffende opleiding om te bespreken wat je kunt doen.', ['https://www.rug.nl/education/contact/study-advisors/']]
#
# Kan ik ook toegelaten worden met deelcertificaten als ik mijn VWO diploma niet haal ['Nee, de Rijksuniversiteit Groningen accepteert geen deelcertificaten.  Als je ouder dan 21 jaar bent, kun je wel een colloquium doctum (toelatingsexamen) doen.  Meer informatie vind je op de pagina Colloquium doctum op onze website.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/colloquium-doctum-']]
#
# Ben ik met een hbo-propedeuse of -diploma toelaatbaar tot een universitaire bacheloropleiding ['Dat is afhankelijk van of je een hbo-propedeuse of een volledige hbo-diploma hebt behaald.   Hbo-propedeuse diploma Je bent niet automatisch toelaatbaar tot een bacheloropleiding. De bacheloropleiding kan aanvullende eisen stellen.  Meer informatie vind je op de pagina HBO-propedeuse op onze website of neem contact op met de studieadviseur van de betreffende opleiding.    Hbo-bachelor diploma  Je bent met een hbo-bachelor diploma toelaatbaar tot een bacheloropleiding. Sommige bacheloropleidingen hebben aanvullende toelatingseisen. Daarnaast is het soms mogelijk om vrijstellingen te krijgen voor bepaalde vakken.  Meer informatie over de aanvullende toelatingseisen vind je op de pagina VWO-diploma op onze website.  Neem voor meer informatie over vrijstellingen contact op met de studieadviseur van de betreffende opleiding.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/toelatingseisen/hbo-propedeuse', 'https://www.rug.nl/education/contact/study-advisors/', 'https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/toelatingseisen/vwo-diploma', 'https://www.rug.nl/education/contact/study-advisors/']]
#
# Maakt het uit welke hbo-propedeuse ik heb gehaald als ik naar de universiteit wil ['Ja, je bent niet automatisch toelaatbaar tot een bacheloropleiding. De bacheloropleiding kan aanvullende eisen stellen.  Meer informatie vind je op de pagina HBO-propedeuse op onze website of neem contact op met de studieadviseur van de betreffende opleiding.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/toelatingseisen/hbo-propedeuse', 'https://www.rug.nl/education/contact/study-advisors/']]
#
# Kan ik instromen in een hoger studiejaar ["Dat is afhankelijk van je hbo-opleiding en de opleiding die je wilt gaan volgen aan de Rijksuniversiteit Groningen.   Meer informatie vind je op de pagina Pre-masterprogramma's op onze website.", ['https://www.rug.nl/education/verkort/']]
#
# Kan ik met een hbo-bachelordiploma instromen in een masterprogramma ["Nee, je kunt met een hbo-bachelordiploma niet meteen aan een masteropleiding beginnen. Soms is het mogelijk om via een pre-masterprogramma in te stromen in een masteropleiding.  Meer informatie vind je op de pagina Pre-masterprogramma's op onze website.", ['https://www.rug.nl/education/verkort/']]
#
# Heb ik recht op extra studiefinanciering ['Nee, je hebt geen recht op extra studiefinanciering.  Meer informatie vind je op de pagina Een master gaan doen op de website van DUO.', ['https://duo.nl/particulier/opleiding-stoppen-of-wijzigen/een-master-gaan-doen.jsp']]
#
# Kan ik stoppen als het niet bevalt ['Ja, je kunt via Studielink een verzoek tot uitschrijven indienen.  Meer informatie vind je op de pagina Uitschrijven op onze website.', ['https://www.rug.nl/education/nederlandse-studenten/uitschrijven/']]
#
# Ben ik met een buitenlandse diploma toelaatbaar tot de universiteit ['Dat is afhankelijk van de buitenlandse diploma.  Meer informatie vind je in:    Bachelor admissions guide   Master admissions guide', ['https://www.rug.nl/education/bachelor/international-students/admission-and-application/application-admission-procedure/', 'https://www.rug.nl/education/master/international-students/admission-and-application/application-admission-procedure/']]
#
# Toelating via het voorbereidend jaar voor anderstaligen ['Het VBJ bereidt hoger opgeleide anderstaligen voor op een studie aan de Hanzehogeschool Groningen of de Rijksuniversiteit Groningen.  Meer informatie vind je op de pagina Voorbereidend Jaar (VBJ) op onze website.', ['https://www.rug.nl/education/bachelor/international-students/admission-and-application/refugee-student/preparatory-year']]
#
# Ik heb niet de juiste vooropleiding. Kan ik dan toch naar de universiteit ['Als je geen diploma hebt dat rechtstreeks toelating biedt tot een universitaire opleiding, kun je je niet als student inschrijven aan de Rijksuniversiteit Groningen. Er zijn wel andere mogelijkheden:  Je kunt je bij sommige opleidingen inschrijven voor open colleges. Als je ouder bent dan 21 jaar kun je mee doen aan het colloquium doctum (toelatingsexamen). Als je jonger bent dan 21 jaar is het wellicht mogelijk om een propedeuse van een hbo-opleiding of het vwo-diploma te halen.  Bij de Open Universiteit is het wel mogelijk om modules te volgen zonder dat je een diploma hoeft te overleggen.', ['https://www.rug.nl/corporate/onderwijs/opleidingen/open', 'http://www.ou.nl/']]
#
# Ik heb een havo-diploma. Wat zijn de mogelijkheden ['Na de havo kun je een jaar naar een hbo-instelling gaan om je hbo-propedeuse te halen. In principe geeft iedere hbo-propedeuse toegang tot de universiteit. Sommige bacheloropleidingen kennen daarnaast bepaalde ingangseisen. Neem contact op met de faculteit voor meer informatie over deze ingangseisen. Als je 21 jaar of ouder bent, is het wellicht ook mogelijk om een colloquium doctum te doen.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/colloquium-doctum-']]
#
# Toelating via het voorbereidend jaar voor anderstaligen ['Velden gemarkeerd met  zijn verplicht', []]
#
# Colloquium doctum ['Informatie over het colloquium doctum en de aanmeldingsprocedure vind je op de pagina Colloquium doctum op onze website.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/colloquium-doctum-']]
#
# Kan ik met een universitair bachelordiploma instromen in een masterprogramma van de RUG ["Ieder masterprogramma heeft eigen toelatingsvoorwaarden. Bij de meeste masterprogramma’s is de bachelor die daar aan vooraf gaat voldoende. Soms zijn aanvullende eisen gesteld.  Meer informatie vind je op de masteropleidingspagina's en de pagina Inschrijfprocedure masteropleiding op onze website.", ['https://www.rug.nl/masters/', 'https://www.rug.nl/education/master/nederlandse-studenten/aanmelding-en-inschrijving/inschrijfprocedure-masteropleiding']]
#
# Ik wil beginnen aan mastervakken en heb mijn bacheloropleiding nog niet afgerond. Kan ik me alvast registreren voor de masteropleiding ['Nee, dat kan niet. Je kunt alleen aan een masteropleiding beginnen als je in het bezit bent van een bachelordiploma.', []]
#
# Hoe meld ik me aan voor een researchmaster of andere master met aanvullende toelatingseisen ['Informatie over de inschrijfprocedure voor Nederlandse studenten vind je op de pagina Inschrijfprocedure masteropleiding op onze website.  Informatie over de inschrijfprocedure voor internationale studenten en Nederlandse studenten met een buitenlandse vooropleiding vind je op de pagina Admissions guide op onze website.', ['https://www.rug.nl/education/master/nederlandse-studenten/aanmelding-en-inschrijving/inschrijfprocedure-masteropleiding', 'https://www.rug.nl/education/master/international-students/admission-and-application/application-admission-procedure/']]
#
# Wat is een verklaring toelating tot het afsluitend examen (VTAE) ['Je hebt een VTAE nodig als je niet automatisch toelaatbaar bent tot een opleiding. De VTAE kun je aanvragen bij de onderwijsadministratie van de betreffende faculteit.  ', ['https://www.rug.nl//education/contact/onderwijsadministraties']]
#
# Wat is een numerus fixusopleiding ['Een numerus fixusopleiding is een bacheloropleiding waar een beperkt aantal plaatsen beschikbaar zijn. Door middel van selectie en het toekenen van rangnummers wordt bepaald wie een plaats aangeboden krijgt.  Belangrijk Meld je uiterlijk 15 januari via Studielink aan voor een numerus fixusopleiding als je mee wilt doen met de seelctieprocedure.     ', []]
#
# Voor welke opleidingen aan de Rijksuniversiteit Groningen is er een selectie ['Op de pagina Selectie en Plaatsing vind je een overzicht van de numerus fixusopleidingen aan de Rijksuniversiteit Groningen. Verder vind je op deze pagina meer informatie over de selectieprocedure.     ', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/selectie-en-plaatsing/']]
#
# Hoe zit het met de matching ['Je valt niet onder de matching als je je hebt aangemeld voor een numerus fixusopleiding en je hebt deelgenomen aan de selectieprocedure.  Als op 15 januari blijkt dat de aanmeldingen voor een numerus fixusopleiding lager of gelijk zijn aan het aantal beschikbare plaatsen vindt er geen selectie plaats. Studenten met een Nederlandse vooropleiding  doen mee aan de matching.     ', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/matching']]
#
# Hoe meld ik me aan voor een numerus fixusopleiding ['Je meldt je via Studielink aan. De deadline is 15 januari.', ['https://www.studielink.nl']]
#
# Voor hoeveel numerus fixusopleiding kan ik mij aanmelden ['Je mag je per studiejaar voor maximaal twee numerus fixusopleidingen aanmelden, behalve voor Geneeskunde en Tandheelkunde.  Dit betekent dat je je niet voor twee geneeskunde-opleidingen kunt aanmelden, maar wel voor Geneeskunde en een andere opleiding met een numerus fixus. Bijvoorbeeld: Tandheelkunde  Let op Als je voor beide fixusopleidingen wordt geselecteerd, moet je een keuze maken. Je mag je maar voor één fixusopleiding inschrijven.  ', []]
#
# Ik sta al bij de RUG ingeschreven en wil meedoen aan de selectie voor een fixusopleiding. Moet ik me ook aanmelden bij Studielink ['Ja, iedereen die wil meedoen aan de selectie voor een numerus fixusopleiding moet zich voor 15 januari hebben aangemeld bij Studielink.', ['https://www.studielink.nl']]
#
# Ik heb al een HBO-V diploma en wil geneeskunde studeren. Moet ik meedoen aan de selectie ['Je kunt meedoen aan de selectie, maar met een HBO-V diploma kun je ook mee doen aan de Pre-Master Geneeskunde (zij-instroom).  ', ['https://www.rug.nl/umcg/onderwijs/opleidingen/geneeskunde/geneeskundegids/zijinstroom/index']]
#
# Moeten mijn persoonsgegevens geverifieerd zijn voordat ik mee kan doen aan de selectie ['Ja, je persoonsgegevens moet uiterlijk 15 februari geverifieerd zijn.   De verificatie gebeurt door je persoonsgegevens te vergelijken met de actuele gegevens in de Basisregistratie Personen (BRP).  Als dit niet lukt, moet je een uittreksel uit het bevolkingsregister en/of een kopie van je paspoort inleveren bij de Centrale Studenten Administratie.   Let op  Je paspoort moet op 1 September nog wel geldig zijn.  ', ['https://www.rug.nl/csa']]
#
# Hoe vaak mag ik mee doen aan de selectie ['Afhankelijk van de opleiding mag je één, twee of maximaal drie keer meedoen aan een selectie. Hierbij tellen de pogingen uit het verleden mee.   ', []]
#
# Hoe weet ik of ik al een selectiepoging hebt verbruikt ['Eind september vind je in Studielink het aantal verbruikte selectiepogingen.  ', []]
#
# Wat moet ik doen als het aantal geregistreerde selectiepogingen niet klopt ['Neem voor 1 september via het formulier Selectie en Plaatsing contact op als het aantal geregistreerde selectiepogingen bij de Rijksuniversiteit Groningen volgens jou niet klopt.  ', ['https://www.rug.nl/formuliersenp']]
#
# Voor welke datum moet ik mij aanmelden in Studielink ['Meld je voor 15 januari in Studielink aan voor een numerus fixusopleiding.  Inleveren extra informatie Lever ook voor 15 januari de extra informatie in als de opleiding hierom vraagt. Kijk voor meer informatie op de opleidingspagina:   Geneeskunde   International Business   International Relations and International Organization (IRIO)  Kunstmatige Intelligentie   Psychologie   Tandheelkunde      ', ['https://www.rug.nl/umcg/education/medicine/decentrale-selectie-geneeskunde', 'https://www.rug.nl/feb/education/study-programmes/numerus-fixus-bsc-ib/', 'https://www.rug.nl/let/organization/bestuur-afdelingen-en-medewerkers/afdelingen/afdeling-ibio/admission', 'https://www.rug.nl/bachelors/artificial-intelligence/', 'https://www.rug.nl/gmw/psychology/education/bachelor/about-selection', 'https://www.rug.nl/umcg/education/dentistry/decentrale-selectie-tandheelkunde-2017---2018']]
#
# Wanneer weet ik of ik ben geselecteerd ['Op 15 april worden de rangnummers bekend gemaakt en het bewijs van toelating gestuurd naar de studenten die zijn geplaatst. Dit gebeurt via Studielink.  ', ['https://www.studielink.nl']]
#
# Wat moet ik doen als ik ben geselecteerd ['Accepteer het bewijs van toelating binnen twee weken!  Je moet het bewijs van toelating binnen twee weken na de dag van ontvangst accepteren. Dit doe je via Studielink.  Doe je dit niet dan vervalt je plaats en wordt deze automatisch aangeboden aan een andere student.  ', ['https://www.studielink.nl']]
#
# Wat gebeurt er als ik wel ben geselecteerd, maar mijn diploma niet haal ['Je kunt deze selectiepoging ongedaan laten maken. Hierdoor verlies je geen selectiepoging en kun je volgend jaar weer meedoen.  Dien voor 1 september via dit formulier een verzoek in (formulier is binnenkort beschikbaar) Stuur de gevraagde bewijsstukken mee.', []]
#
# Waar vind ik meer informatie over de selectie ["Op de pagina Selectie en Plaatsing vind je de algemene informatie over de selectie.   Specifieke informatie over de selectieprocedure en -criteria vind je op de opleidingspagina's:   Geneeskunde   International Business   International Relations and International Organization (IRIO)  Kunstmatige Intelligentie   Psychologie   Tandheelkunde      ", ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/selectie-en-plaatsing/', 'https://www.rug.nl/umcg/education/medicine/decentrale-selectie-geneeskunde', 'https://www.rug.nl/feb/education/study-programmes/numerus-fixus-bsc-ib/', 'https://www.rug.nl/let/organization/bestuur-afdelingen-en-medewerkers/afdelingen/afdeling-ibio/admission', 'https://www.rug.nl/bachelors/artificial-intelligence/', 'https://www.rug.nl/gmw/psychology/education/bachelor/about-selection', 'https://www.rug.nl/umcg/education/dentistry/decentrale-selectie-tandheelkunde-2017---2018']]
#
# Hoe kan ik bezwaar aantekenen ['Je kunt via het Centraal Loket Rechtsbescherming Studenten (CLRS) een bezwaar indienen tegen besluiten met betrekking tot de selectie.  De bezwaartermijn bedraagt zes weken.     ', ['https://www.rug.nl/clrs']]
#
# Wat is matching en waarom moet ik meedoen ['In de wet staat dat aankomend studenten die zich voor het eerst aanmelden voor een studie zonder selectie het recht hebben om deel te nemen aan een studiekeuzeactiviteit. Teveel studenten stoppen met hun studie in het eerste jaar, vaak doordat ze geen goed beeld hadden van de studie. Door deel te nemen aan matchingsactiviteiten krijg je een reëel beeld van de studie en heb je de mogelijkheid om je verwachtingen te checken. Past de studie die ik heb gekozen bij mij? En pas ik bij de studie? Sluit de opleiding aan bij mijn interesses en capaciteiten?   Voor alle opleidingen zonder numerus fixus van de faculteiten Gedrags- en Maatschappijwetenschappen, Medische Wetenschappen, Rechtsgeleerdheid, Science and Engineering en Wijsbegeerte is deelname aan matching verplicht om ingeschreven te worden. Wil je meer weten over de matchingsprocedure van jouw faculteit? Bekijk dan de facultaire matchingpagina.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/matching']]
#
# Hoe ziet matching er uit ['De matchingsprocedure verschilt per faculteit. Je ontvangt meer informatie over de procedure als je je voor 1 juli via Studielink hebt aangemeld voor het eerste jaar van een bacheloropleiding.   Na deelname aan de matchingsprocedure ontvang je van de opleiding een studiekeuzeadvies. Indien je een positief advies ontvangt van de opleiding, betekent dit dat de opleiding op basis van de matching geen reden ziet waarom je niet bij de opleiding zou passen. Indien je een heroverwegingsadvies ontvangt na voltooiing van de matchingprocedure, houdt dit in dat de opleiding je op basis van de matching adviseert om je studiekeuze te heroverwegen. Dit advies is echter niet bindend, wat inhoudt dat het je alsnog vrij staat om met deze opleiding te beginnen. Deelname aan de matchingsprocedure is echter wel bindend. Als je de machtingsprocedure niet voltooit, kun je niet worden ingeschreven.  Meer informatie vind je op de pagina Matching aan de RUG op onze website.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/matching']]
#
# Is matching hetzelfde als selectie ['Matching is niet hetzelfde als selectie. De bedoeling van matching is dat aankomende studenten ertoe aangezet worden om er goed over na te denken of de gekozen studie goed bij hem/haar past. De uitslag van de matchingsprocedure is niet bindend, waar dit bij selectie wel het geval is.  Meer informatie over machtingsprocedure vind je op de pagina Matching aan de RUG op onze pagina.  Meer informatie over de selectieprocedure voor numerus fixusopleiding vind je op de pagina Selectie en Plaatsing op onze website.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/matching', 'https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/selectie-en-plaatsing/']]
#
# Is er matching bij alle opleidingen ['Elke opleiding biedt de mogelijkheid tot matching aan, maar het is niet bij elke faculteit verplicht. Bij de volgende opleidingen/faculteiten is het verplicht:  Faculteit Rechtsgeleerdheid Faculteit Gedrags- en Maatschappijwetenschappen Faculty of Science and Engineering Faculteit Wijsbegeerte Bewegingswetenschappen (Faculteit Medische Wetenschappen)  De numerus fixusopleidingen hebben geen matching. Voor deze opleidingen geldt een andere procedure.  Meer informatie over de procedure voor numerus fixus-opleidingen vind je op pagina Selectie en plaatsing op onze website. Ben je niet geselecteerd bij een numerus fixus-opleiding en wil je een andere opleiding aan de RUG gaan doen? Meld je dan op uiterlijk 31 juli aan in Studielink.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/selectie-en-plaatsing/']]
#
# Wanneer zijn de matchingsdagen ['Veel studies hebben hun matchingsdag in juni, sommige (deels) eerder. Kijk voor een overzicht van de data op de pagina Matching aan de RUG.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/matching']]
#
# Wat als ik niet kan komen op de matchingsdag ['Deelname aan matching is niet verplicht, met uitzondering van de faculteiten Gedrags- en Maatschappijwetenschappen, Medische Wetenschappen, Rechtsgeleerdheid, Science and Engineering en Wijsbegeerte. De numerus fixus-opleidingen bij deze faculteiten hebben geen matching, voor deze opleidingen geldt een andere procedure. In het geval dat je niet kunt meedoen aan de matchingsdag, geef dit dan aan bij de opleiding. De opleiding bepaalt vervolgens wat er verder gebeurt.', []]
#
# Als ik geïnteresseerd ben in twee studies kan ik dan naar twee matchingsdagen ['Dit is mogelijk, indien dit uitkomt.', []]
#
# Wat als de opleiding niet bij me past ['Kom je er na deelname aan matching achter dat de opleiding toch niet bij je past, dan zal je opnieuw een keuze moeten maken. Indien je hier hulp bij nodig hebt, dan kun je je wenden tot het Studenten Service Centrum (SSC). Daarnaast heeft iedere opleiding een studieadviseur, bij wie je terecht kan voor vragen. Houd er rekening mee dat je je op uiterlijk 31 juli moet aanmelden voor een andere opleiding als je er na matching achter komt dat een opleiding niet bij je past.', ['https://www.rug.nl/ssc', 'https://www.rug.nl/education/contact/study-advisors/']]
#
# Wat kan ik doen als ik voor of na matching studiekeuzevragen heb ['Mocht je nog verdere vragen hebben omtrent je studiekeuze, neem dan contact op met het Studenten Service Centrum. Zij kunnen je helpen met het beantwoorden van je vragen.  De contactgegevens vind je op de pagina Studenten Service Centrum.', ['https://www.rug.nl/ssc']]
#
# Wanneer heb ik aan de studiekeuzecheck voldaan ['Je hebt voldaan aan de studiekeuzecheck op het moment dat je aan alle matchingactiviteiten van de opleiding hebt deelgenomen en je een studiekeuzeadvies hebt ontvangen. Het maakt voor het voltooien van de studiekeuzecheck geen verschil of je een oranje of een groen advies hebt ontvangen.', []]
#
# Hoe schrijf ik me in bij de RUG ["De inschrijfprocedure die je moet volgen, is afhankelijk van de door jou gekozen opleiding, je vooropleiding en het feit of je al eens ingeschreven hebt gestaan aan de RUG.  Informatie over de inschrijfprocedures voor Nederlandse studenten vind je op de onderstaande pagina's op onze website:    Bachelor aanmelding en inschrijving   Master aanmelding en inschrijving      ", ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/', 'https://www.rug.nl/education/master/nederlandse-studenten/aanmelding-en-inschrijving/']]
#
# Moet ik me ieder jaar opnieuw inschrijven ['Ja, je schrijft je voor ieder studiejaar opnieuw in. Een studiejaar loopt van 1 september t/m 31 augustus.     ', []]
#
# Tot wanneer kan ik me inschrijven ['Je wordt per 1 september ingeschreven als je voor 31 augustus via Studielink:  een herinschrijvingsverzoek hebt ingediend, én de betaling van het collegegeld hebt geregeld.   Te laat? De inschrijving wordt opgeschoven naar het eerstvolgende inschrijfmoment van de opleiding.   bacheloropleiding: 1 september. Na 1 september kun je alleen ingeschreven worden met toestemming van de opleiding. Neem voor meer informatie contact op met de studieadviseur.  masteropleiding: eerstvolgende instroommoment van de betreffende masteropleiding (studievertraging: maximaal een half jaar).     ', ['https://www.studielink.nl/', 'https://www.rug.nl/education/contact/study-advisors/', 'https://www.rug.nl/education/master/nederlandse-studenten/aanmelding-en-inschrijving/instroommomenten-masteropleidingen']]
#
# Kan ik me later in het studiejaar inschrijven ["Dat is afhankelijke van het instroommoment van de door jou gekozen opleiding.   Meer informatie vind je op de onderstaande pagina's op onze website:   Bachelor aanmelding en inschrijving   Instroommomenten masteropleidingen      ", ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/', 'https://www.rug.nl/education/master/nederlandse-studenten/aanmelding-en-inschrijving/instroommomenten-masteropleidingen']]
#
# Studielink geeft aan dat ik mij binnen tien dagen moet inschrijven, omdat anders mijn plaatsingsbewijs vervalt. ['De mededeling over het plaatsingsbewijs is alleen bedoeld voor studenten van de Rijksuniversiteit Groningen, die zich willen inschrijving voor een lotingstudie. Je kunt deze mededeling negeren als je het volgende geregeld hebt:   Je inschrijving via Studielink. De betaling van je collegegeld. Een pasfoto voor de RUGpas uploaden via de app op de Student Portal.   Tip!  Op je persoonlijke pagina in Studielink kun je het hele (her)inschrijvingsproces volgen.    ', ['https://www.studielink.nl/', 'https://www.rug.nl/education/documenten/admission/instruction-uploaden-photo-university-card.pdf', 'https://www.studielink.nl/']]
#
# Hoe word ik op de hoogte gehouden van mijn inschrijvingsverzoek ['Je kunt de status van je inschrijvingsverzoek volgen op je persoonlijke Studielinkpagina onder de optie Mijn inschrijvingen. Daarnaast wordt je op de hoogte gehouden van elke wijziging via e-mail en via Berichten in Studielink.   ', ['https://www.studielink.nl']]
#
# Wanneer moet ik me inschrijven als ik vakken wil volgen, die pas in het tweede half jaar worden gegeven ['Het moment van inschrijven is afhankelijk van het instroommoment van de betreffende bachelor- of masteropleiding:   Bacheloropleiding: 1 september. Na 1 september kun je alleen ingeschreven worden met toestemming van de opleiding. Neem voor meer informatie contact op met de studieadviseur.  Masteropleiding: instroommomenten van de betreffende masteropleiding.        ', ['https://www.rug.nl/education/contact/study-advisors/', 'https://www.rug.nl/education/master/nederlandse-studenten/aanmelding-en-inschrijving/instroommomenten-masteropleidingen']]
#
# Hoe weet ik dat mijn (her)inschrijving in orde is ['Op je persoonlijke pagina in Studielink kun je het hele inschrijvingsproces volgen. Wanneer je officieel bent ingeschreven verschijnt op deze pagina de datum van inschrijving.  Nieuwe RUG-studenten ontvangen daarnaast een RUGpas op hun correspondentieadres.     ', ['https://www.studielink.nl']]
#
# Ik stond vorig studiejaar niet ingeschreven. Hoe kan ik me weer inschrijven ["Dien via Studielink een inschrijvingsverzoek in voor een bachelor- of masteropleiding aan de Rijksuniversiteit Groningen.   Informatie over de inschrijfprocedures voor Nederlandse studenten vind je op de onderstaande pagina's op onze website:   Bachelor aanmelding en inschrijving   Master aanmelding en inschrijving      ", ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/', 'https://www.rug.nl/education/master/nederlandse-studenten/aanmelding-en-inschrijving/']]
#
# Houd ik mijn eigen studentnummer als ik me weer opnieuw in wil schrijven ['Je houdt in principe je eigen studentnummer. Ook al heb je jarenlang niet ingeschreven gestaan.  Uitzondering  Je krijgt een nieuw studentnummer als je sinds 1982 niet meer ingeschreven hebt gestaan in het Hoger Onderwijs. Neem contact op met de Centrale Studenten Administratie.   ', ['https://www.rug.nl/csa']]
#
# Wat is een pre-masterprogramma ['Een pre-masterprogramma is een speciaal programma voor HBO studenten die een verwante masteropleiding willen volgen aan de Rijksuniversiteit Groningen.     ', ['https://www.rug.nl/education/master/nederlandse-studenten/studiekeuze-en-voorlichting/pre-master/']]
#
# Hoe schrijf ik me in voor een pre-masterprogramma ["Raadpleeg de handleiding 'Hoe doe je een aanmelding als Pre-Master' op pagina 'Pre-masterprogramma's'.     ", ['https://www.rug.nl/education/master/nederlandse-studenten/studiekeuze-en-voorlichting/pre-master/']]
#
# Ik ga halverwege het studiejaar aan mijn master beginnen. Moet ik me er alvast voor inschrijven ['Je kunt alleen ingeschreven worden voor een masteropleiding als je in het bezit bent van een bachelordiploma. Daarnaast kunnen er aanvullende toelatingseisen zijn.    Meer informatie    Overzicht instroommomenten masteropleidingen.  Inschrijfprocedure masteropleiding.     ', ['https://www.rug.nl/education/master/nederlandse-studenten/aanmelding-en-inschrijving/instroommomenten-masteropleidingen', 'https://www.rug.nl/education/master/nederlandse-studenten/aanmelding-en-inschrijving/inschrijfprocedure-masteropleiding']]
#
# Ik ga volgend jaar een andere opleiding doen aan de RUG, dan dit jaar. Hoe geef ik dit aan ['Tijdens de herinschrijvingsprocedure via Studielink kun je aangeven dat je je voor een andere opleiding wilt herinschrijven.   ', []]
#
# Ik doe twee studies aan de RUG, maar ik wil met één daarvan stoppen. Hoe doe ik dat ['Klik hier voor het formulier', ['https://www.rug.nl/education/faq/?tcid=verint_3_7394_8936']]
#
# Hoe verander ik van studie tijdens het collegejaar ['Als je tijdens het studiejaar van opleiding wilt veranderen, moet je het volgende doen:   Bespreek je plan met de studieadviseur van je nieuwe opleiding om vast te stellen wat de mogelijkheden zijn. Dien via Studielink een nieuw inschrijvingsverzoek in. Geef aan DUO door dat je van opleiding bent veranderd.     ', ['https://www.rug.nl/education/contact/study-advisors/', 'https://www.studielink.nl', 'http://www.duo.nl/']]
#
# Ik sta ingeschreven bij de RUG en ik wil me ook inschrijven bij een andere instelling. Wat moet ik doen ['Je regelt de inschrijving volgens de procedure van de andere instelling. Daarnaast laat je het ook weten aan DUO.   Betaling collegegeld  Als je bij twee erkende instellingen in het Hoger Onderwijs staat ingeschreven hoef je in principe slechts een keer collegegeld te betalen. Je rechten op studentenvoorzieningen zijn verbonden aan de instelling waar je als eerste stond ingeschreven en waar je je collegegeld aan hebt betaald. Vraag bij Information Services een Bewijs Betaald Collegegeld (BBC) aan. Dit overhandig je aan de andere instelling zodat je daar geen collegegeld hoeft te betalen.         ', ['http://www.duo.nl/', 'https://www.rug.nl/education/information-services/']]
#
# Ik wil twee studies doen aan de RUG. Kan dat Hoe regel ik dat ['Ja, je mag voor meerdere opleidingen ingeschreven staan aan de Rijksuniversiteit Groningen.   Bespreek met de studieadviseurs van beide opleidingen of je toelaatbaar bent, of je plannen in praktijk haalbaar zijn en hoe je je studies zo handig mogelijk inricht. Je schrijft je via Studielink in voor de tweede opleiding. Op deze pagina staat precies beschreven hoe je dat moet doen. Vergeet niet om aan DUO door te geven dat je er een tweede opleiding bij gaat doen.   ', ['https://www.studielink.nl', 'https://www.rug.nl/education/bachelor/nederlandse-studenten/financien/collegegeld/tarieven/collegegeld-voor-een-tweede-opleiding-van-dezelfde-graad', 'http://www.duo.nl/']]
#
# Kan ik mijn inschrijving annuleren ['Ja, je kunt je inschrijving voor de startdatum van je opleiding annuleren via Studielink.  Meer informatie vind je op pagina Annuleren van je inschrijving op onze website.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/cancel-admission']]
#
# Inschrijfprocedure niet-Nederlandse vooropleiding ["International students and Dutch students with non-Dutch qualifications are not automatically admitted to a bachelor's degree programme at the University of Groningen. The full registration procedure will take longer than for Dutch students with regular Dutch qualifications and consists of three steps: application, admission and registration.", []]
#
# Instroommomenten ["Je kunt op vaste momenten in jaar beginnen met een bachelor of masteropleiding.  Meer informatie over deze instroommomenten vind je op de onderstaande pagina's op onze website:   Bachelor: instroommomenten   Master: instroommomenten", ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/', 'https://www.rug.nl/education/master/nederlandse-studenten/aanmelding-en-inschrijving/instroommomenten-masteropleidingen']]
#
# Hoe kan ik mij herinschrijven ['Dien in de periode 1 juni t/m 31 augustus een herinschrijvingsverzoek in via Studielink.   Meer informatie vind je op de Student Portal pagina Herinschrijvingsprocedure.  ', ['https://student.portal.rug.nl/infonet/studenten/inuitschrijving/inschrijven/herinschrijven']]
#
# Wat moet ik doen als het niet lukt om via Studielink een herinschrijving te doen ['Neem contact op met Information Services.', ['https://www.rug.nl/education/information-services/']]
#
# Wat moet ik doen als ik me niet wil herinschrijven ['Geef in Studielink aan dat je stopt met je opleiding.  Meer informatie vind je in één van de handleidingen van Studielink.', ['https://www.rug.nl/education/hoezithet/veelgestelde-vragen?tcid=bureau_2_1597_4585']]
#
# Moet ik mij herinschrijven als ik nog niet weet of ik voor 1 september afstudeer ['Neem voor advies contact op met Information Services.', ['https://www.rug.nl/education/information-services/']]
#
# Moet ik mij nog herinschrijven als ik mijn diploma in september krijg ['Nee, je hoeft je niet opnieuw in te schrijven als je zeker weet dat je afstudeerdatum voor september ligt.   Neem bij twijfel contact op met Information Services.', ['https://www.rug.nl/education/information-services/']]
#
# Kan ik mij voor een maand herinschrijven als ik nog maar één onderdeel van mijn opleiding moet afronden ['In principe schrijf je je voor een jaar in.  Maar na het afronden van je opleiding, kun je altijd een verzoek tot uitschrijven indienen.  Afhankelijk van je opleiding kun je je op verschillende momenten in het jaar inschrijven.   Instroommomenten bacheloropleidingen   Instroommomenten masteropleidingen   Meer informatie vind je op de pagina Uitschrijven en Afstuderen op onze website.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/', 'https://www.rug.nl/education/master/nederlandse-studenten/aanmelding-en-inschrijving/instroommomenten-masteropleidingen', 'https://www.rug.nl/education/nederlandse-studenten/uitschrijven/', 'https://www.rug.nl/education/nederlandse-studenten/uitschrijven/afstuderen']]
#
# Hoe moet ik mij uitschrijven ['Dien via Studielink een verzoek tot uitschrijven in.  ', ['http://info.studielink.nl/nl/studenten/stappenplanstudielink/Pages/Default.aspx']]
#
# Word ik na mijn afstuderen automatisch uitgeschreven ['Nee, je wordt na je afstuderen niet automatisch uitgeschreven. Je moet zelf een verzoek tot uitschrijven indienen via Studielink.  Meer informatie vind je op de Student Portal pagina Afstuderen.  ', ['https://student.portal.rug.nl/infonet/studenten/inuitschrijving/uitschrijven/afstuderen']]
#
# Per wanneer word ik uitgeschreven ['Dit is afhankelijk van de reden waarom je je wilt uitschrijven.           Reden Uitgeschreven met ingang van   Stoppen met opleiding eerste van de volgende maand na indienen verzoek   Afstuderen eerste van de maand volgend op de maand waarin het examen is behaald    Overlijden datum van overlijden           Meer informatie over Uitschrijven en Afstuderen vind je op de Student Portal.   ', ['https://student.portal.rug.nl/infonet/studenten/inuitschrijving/uitschrijven/', 'https://student.portal.rug.nl/infonet/studenten/inuitschrijving/uitschrijven/afstuderen']]
#
# Ik doe twee studies aan de RUG, en ik wil met een daarvan stoppen. Hoe doe ik dat ['Dien via Studielink een verzoek tot uitschrijving in voor één van de opleidingen.  Meer informatie vind je op de pagina Uitschrijven op de Student Portal.  ', ['https://www.studielink.nl', 'https://student.portal.rug.nl/infonet/studenten/inuitschrijving/uitschrijven/']]
#
# Wat moet ik doen als ik een verkeerde uitschrijvingsdatum in Studielink heb ingevuld ['Neem zo snel mogelijk contact op met Information Services.  ', ['https://www.rug.nl/education/information-services/']]
#
# Kan ik mijn verzoek tot uitschrijven terugdraaien ['Je kunt dit niet zelf wijzigen in Studielink. Neem zo snel mogelijk contact op met Information Services.  ', ['https://www.rug.nl/education/information-services/']]
#
# Restitutie collegegeld ["Je hebt recht op een teruggave (restitutie) van 1/12 van het collegegeld voor elke maand van het studiejaar dat je niet meer staat ingeschreven.  Let op: Over de maanden juli en augustus vind geen restitutie plaats.  Meer informatie vind je op de onderstaande pagina's op onze website:   Bachelor: Restitutie collegegeld    Master: Restitutie collegegeld", ['https://www.rug.nl/education/bachelor/nederlandse-studenten/financien/collegegeld/restitutie', 'https://www.rug.nl/education/master/nederlandse-studenten/financien/collegegeld/restitutie']]
#
# Gevolgen uitschrijving voor studiefinanciering (DUO) ['Alleen een link gevonden', ['https://duo.nl/particulier/studiefinanciering-stopzetten.jsp']]
#
# Animatiefilmpje over Nieuwe Studielink ['Studielink heeft een animatiefilmpje gemaakt over de veranderingen van Studielink.', ['https://youtu.be/LP9_kYy1BHc']]
#
# Ik heb een Nederlands woonadres ['Als je een Nederlandse woonadres hebt, log je in Studielink in met je DigiD.   Ga naar www.studielink.nl  Klik op <Inloggen met DigiD> Vul de gevraagde gegevens in  Heb je nog geen DigiD? Vraag deze aan via DigiD-website.', ['http://www.studielink.nl/', 'https://www.digid.nl/']]
#
# Ik heb geen Nederlands woonadres ["Als je geen Nederlands woonadres hebt, moet je een Studielink-account aanmaken.   Ga naar www.studielink.nl  Klik op 'Studielink-account aanmaken zonder DigiD Vul de gevraagde gegevens in", ['http://www.studielink.nl/']]
#
# Ik log in met DigiD ['Log vanaf 10 oktober in met je DigiD om je huidige account op de nieuwe Studielink website te activeren.', ['http://www.studielink.nl']]
#
# Wat is Studielink ['Studielink is een landelijke applicatie waar scholieren en (aspirant) studenten hun (her)inschrijving aan een hogeschool of universiteit in Nederland regelen.   Meer informatie over de inschrijfprocedure voor bachelor studenten vind je op de pagina Aanmelden en inschrijven op onze website.   Meer informatie over de inschrijfprocedure voor master studenten vind je op de pagina Aanmelden en inschrijven op onze website.   ', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/', 'https://www.rug.nl/education/master/nederlandse-studenten/aanmelding-en-inschrijving/']]
#
# Waar kan ik terecht met mijn vragen over het gebruik van Studielink ['De meest gestelde vragen en antwoorden over het gebruik van Studielink vind je in de digitale Studielink VRAAGbaak op de website van Studielink.  ', ['http://info.studielink.nl/nl/studenten/vraag/Pages/vraag.aspx']]
#
# Storingen en onderhoud Studielink ['Informatie over storingen en onderhoud bij Studielink vind je op de pagina Storingen & Onderhoud op de website van Studielink.  ', ['http://info.studielink.nl/nl/studenten/Pages/storingen-onderhoud.aspx']]
#
# Studielink stappenplannen ['Er zijn verschillende handleidingen die uitleggen hoe je Studielink gebruikt.   Een overzicht van deze handleidingen vind je op de pagina Stappenplan Studielink op de website van Studielink.', ['http://info.studielink.nl/nl/studenten/stappenplanstudielink/Pages/Default.aspx']]
#
# Wat is een RUG-account ["Met het RUG-account heb je toegang tot universitaire voorzieningen zoals:    Student Portal   Hier vind je de universitaire en studie-gerelateerde informatie en kun je andere voorzieningen starten, zoals:   Cursuscatalogus Cijfers en inschrijvingen Student e-mail (Google Apps for education inclusief agenda, chat, documenten en webpagina's) Elektronische bestanden van de Universiteitsbibliotheek   Studentwerkplekken op diverse locaties.  Je RUG-account bestaat uit je studentnummer en een wachtwoord.", ['http://studentportal.rug.nl/', 'http://student.portal.rug.nl/infonet/studenten/ict/collaboration/google/google']]
#
# Wanneer heb ik recht op een RUG-account ['Iedereen die zich via Studielink voor een opleiding aan de RUG heeft aangemeld krijgt een RUG-account.   Ga je uiteindelijk niet studeren aan de RUG, dan wordt je RUG-account verwijderd.', []]
#
# Hoe kan ik mijn RUG-account activeren ["Je activeert je RUG-account via de Password Self Service Portal.   Vul je studentnummer in (met de 'S' ervoor). Klik op 'gebruikersaccount activeren'. Je ontvangt een code en verdere instructies op je privé e-mailadres. Dit is het e-mailadres dat je in Studielink hebt opgegeven.  Zijn er problemen of heb je vragen? Neem contact op met de CIT servicedesk", ['https://diy.rug.nl/pwm/', 'https://www.rug.nl/society-business/centre-for-information-technology/contact-cit-servicedesk']]
#
# Hoe lang blijft mijn RUG-account actief ['Zolang je ingeschreven staat voor een opleiding aan de RUG blijft je RUG-account actief.', []]
#
# Wanneer krijg ik mijn RUG-account ['Dit is afhankelijk van de startdatum van je opleiding.      Startdatum: 1 september  Je krijgt je RUG-account vanaf 6 januari.  Andere startdatum  Je krijgt je RUG-account een maand voor de startdatum van je opleiding.    Uitzondering: Ben je een exchange student, gaststudent of cursist? Dan krijg je je RUG-account 3 maanden voor de startdatum van hun opleiding.', []]
#
# Wanneer weet ik of mijn RUG-account beschikbaar is ['Je krijgt een e-mail met informatie over het activeren van je RUG-account.', []]
#
# Waarom is mijn RUG-account geblokkeerd ['Je RUG-account kan om verschillende redenen geblokkeerd worden.      Je hebt het collegegeld niet betaald.  Je account wordt geblokkeerd als je na de startdatum van je opleiding het volledige collegegeld niet hebt betaald of geen machtiging hebt afgeven.  Er stond onvoldoende saldo op je rekening (betaling via machtiging)  Je account wordt geblokkeerd, omdat het innen van (een deel) van het collegegeld via de machtiging niet is gelukt. Waarschijnlijk omdat er onvoldoende saldo op je rekening staat.  Je hebt je uitgeschreven.  Je account wordt 8 weken na je uitschrijvingsdatum geblokkeerd.', ['https://www.rug.nl/education/tuition/payment/direct-debit/insufficient-bank-balance']]
#
# Hoe kan ik mijn RUG-account laten deblokkeren ['Dit is afhankelijk van de redenen waarom je RUG-account is geblokkeerd:      Je hebt het collegegeld niet betaald. Betaal binnen 31 dagen het volledige collegegeld of geef een machtiging af. Doe je dit niet? Dan wordt je RUG-account definitief verwijderd.  Er stond onvoldoende saldo op je rekening (betaling via machtiging)  Betaal zo snel mogelijk het betalingstermijn van je machtiging. Meer informatie vind je op de pagina Gevolgen onvoldoende saldo op rekening op onze website.  Je hebt je uitgeschreven.  Je account wordt alleen weer actief als je binnen een jaar na uitschrijven met een nieuwe opleiding begint aan de RUG. De datum waarop je account actief wordt, is afhankelijk van de startdatum van je nieuwe opleiding:   1 september: je account wordt op 1 maart actief. andere datum: je account wordt een maand voor de startdatum van je opleiding actief.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/financien/collegegeld/betalen/digitale-machtiging/gevolgen-onvoldoende-saldo-op-rekening']]
#
# Ik heb (een termijn van) het collegegeld betaald. Wanneer wordt mijn RUG-account gedeblokkeerd ['Dit is afhankelijk van de manier waarop je het collegegeld hebt betaald.      Contact betaald of gepind  Je RUG-account wordt uiterlijk de volgende dag gedeblokkeerd.  Overgemaakt op bankrekening van RUG  Je RUG-account wordt pas gedeblokkeerd als de de betaling binnen is bij de RUG. In extreme gevallen kan dit tien dagen duren.', []]
#
# ...
#
# Universiteitskrant ['Alleen een link gevonden', ['http://www.ukrant.nl/']]
#
# Universiteitsbibliotheek ['Alle studiezalen in de Universiteitsbibliotheek (locaties Binnenstad en Zernike) en de Centrale Medische Bibliotheek (CMB) zijn momenteel gesloten. De dienstverlening is beperkt.', []]
#
# Kennisbank met meest gestelde vragen over ICT ['Een overzicht van de veelgestelde ICT-vragen en handige handleidingen vind je in de ICT kennisbank.  De ICT kennisbank voor studenten vind je op de Student Portal (inloggen met S-nummer). De ICT kennisbank voor medewerkers vind je op My University (inloggen met P-nummer).  Ben je (nog) geen student of medewerker en heb je een ICT vraag? Neem dan contact op met de CIT servicedesk.', ['https://student.portal.rug.nl/infonet/studenten/ict/kennisbank/it-question-faq-student', 'https://myuniversity.rug.nl/infonet/medewerkers/ict/kennisbank/it-question-faq-staff', 'https://www.rug.nl/society-business/centre-for-information-technology/contact-cit-servicedesk']]
#
# Facultaire of opleidingsverenigingen ['Een overzicht van de studieverenigingen en - organisatie vind je op de pagina Faculteits- en studieverenigingen op onze website.', ['https://www.rug.nl/education/find-out-more/extracurricular-activities-associations/']]
#
# Gezelligheidsverenigingen ['Een overzicht van de gezelligheidsvereningingen vind je op de pagina Studentenverenigingen op onze website.', ['https://www.rug.nl/education/find-out-more/extracurricular-activities-associations/student-societies']]
#
# Politieke organisaties ['Een overzicht van de politieke organisaties vind je op de pagina Politieke verenigingen en activiteiten op onze website.', ['https://www.rug.nl/education/find-out-more/extracurricular-activities-associations/political']]
#
# Studentensport ['Informatie over studentensport vind je op de pagina Sport op onze website. Daar vind je ook een overzicht van alle studentensportverenigingen.', ['https://www.rug.nl/education/find-out-more/student-life/sports']]
#
# Culturele verenigingen ['Een overzicht van de culturele verenigingen vind je op de pagina Culturele verenigingen op onze website.', ['https://www.rug.nl/education/find-out-more/extracurricular-activities-associations/cultural']]
#
# Internationale studentenverenigingen ['Een overzicht van internationale studentenverenigingen vind je op de pagina Overzicht van internationale verenigingen op onze website.', ['https://www.rug.nl/education/find-out-more/extracurricular-activities-associations/international-student-associations']]
#
# Facultaire kennisbanken ['In de facultaire kennisbank vind je informatie over o.a. vakken, roosters, boeken, tentamens en afstuderen.   Economie en Bedrijfskunde   Godgeleerdheid en Godsdienstwetenschap   Rechtsgeleerdheid   Ruimtelijke wetenschappen', ['https://www.rug.nl/feb/education/support/', 'https://www.rug.nl/ggw/organization/questions-and-answers/', 'https://www.rug.nl/rechten/kennisbank/', 'https://www.rug.nl/frw/education/prospective-student']]
#
# Studentendecaan ['Alleen een link gevonden', ['https://rug.nl/sp/studentendecaan']]
#
# Studentenpsycholoog ['Alleen een link gevonden', ['https://rug.nl/sp/studentenpsycholoog']]
#
# Aanvraagformulier factuur werkgever ["Het Aanvraagformulier factuur heb je nodig als je werkgever een factuur wil hebben voor het betalen van collegegeld.  Meer informatie en het formulier vind je op de onderstaande pagina's op onze website:   Bachelor: Factuur   Master: Factuur", ['https://www.rug.nl/education/bachelor/nederlandse-studenten/financien/collegegeld/betalen/factuur', 'https://www.rug.nl/education/master/nederlandse-studenten/financien/collegegeld/betalen/factuur']]
#
# Toelating tot bijvak bachelor of master ["Het formulier Toelating tot bijvak bachelor/master heb je nodig als je je wilt inschrijven als bijvakstudent.  Meer informatie vind je op de onderstaande pagina's op onze website:   Bachelor: Inschrijfprocedure bijvakstudent   Master: inschrijfprocedure bijvakstudent", ['https://www.rug.nl/education/documenten/admission/toelating_tot_bijvak_bachelor_of_master.pdf', 'https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/inschrijfprocedure-bijvakstudent', 'https://www.rug.nl/education/master/nederlandse-studenten/aanmelding-en-inschrijving/inschrijfprocedure-bijvakstudent']]
#
# Verklaring toelating afsluitend examen (VTAE) ['Je hebt een VTAE nodig als je niet automatisch toelaatbaar bent tot een opleiding. De VTAE kun je aanvragen bij de onderwijsadministratie van de betreffende faculteit.  ', ['https://www.rug.nl//education/contact/onderwijsadministraties']]
#
# Klachtenformulier (CLRS) ['Het klachtenformulier heb je nodig als je een klacht wilt indienen bij het Centraal Loket Rechtsbescherming Studenten (CLRS).  ', ['https://www.rug.nl/education/laws-regulations-complaints/complaintobjectionappeal']]
#
# Bezwaar- en beroepformulier (CLRS) ['Het bezwaar- en beroepformulier heb je nodig als je een bezwaar of een beroep wilt indienen bij het Centraal Loket Rechtsbescherming Studenten (CLRS).  ', ['https://www.rug.nl/education/laws-regulations-complaints/complaintobjectionappeal']]
#
# Verklaring van inschrijving ["Een verklaring van inschrijving gebruik je onder andere voor niet-universitaire instanties, zoals (ziektekosten)verzekering, pensioen- en wezenfonds, en vaar- en vervoerdiensten.  Daarnaast kan een studentenvereniging je vragen om een verklaring van inschrijving.   Download de verklaring van inschrijving via   de app 'Inschrijving en foto' (RUG tools) op de Student Portal (inloggen met je S-nummer en wachtwoord).   Je kunt een verklaring van inschrijving met officiële stempel op twee manieren aanvragen   Vul het Aanvraagformulier verklaringen in en ontvang de verklaring per post of e-mail. Haal de verklaring persoonlijk op bij de Centrale Studenten Administratie.", ['http://myuniversity.rug.nl/portal/', 'https://www.rug.nl/education/contact/information-services/application-form-statements', 'https://www.rug.nl/csa']]
#
# Verklaring betaald collegegeld ['Je kunt een verklaring betaald collegegeld op twee manieren aanvragen:  Vul het Aanvraagformulier verklaring in en ontvang de verklaring per post. Haal de verklaring persoonlijk op bij de Centrale Studenten Administratie.', ['https://www.rug.nl/education/contact/information-services/application-form-statements', 'https://www.rug.nl/csa']]
#
# Examenverklaring ['Je kunt een examenverklaring op twee manieren aanvragen:  Vul het Aanvraagformulier verklaring in en ontvang de verklaring per post of e-mail. Haal de verklaring persoonlijk op bij de Centrale Studenten Administratie.', ['https://www.rug.nl/education/contact/information-services/application-form-statements', 'https://www.rug.nl/csa']]
#
# Gewaarmerkte kopie diploma RUG ['Je kunt een gewaarmerkte kopie van je RUG-diploma op drie manieren aanvragen:  Download een uittreksel van je diploma via het diplomaregister van DUO. Een digitaal uittreksel uit het diplomaregister heeft dezelfde waarde als een papieren gewaarmerkte kopie. Vul het Aanvraagformulier verklaring in en ontvang het gewaarmerkte kopie per post of e-mail. Haal de gewaarmerkte kopie persoonlijk op bij de Centrale Studenten Administratie.', ['http://www.duo.nl/particulieren/diplomas/over-mijn-diploma/uittreksel-diplomagegevens-downloaden.asp', 'https://www.rug.nl/education/contact/information-services/application-form-statements', 'https://www.rug.nl/csa']]
#
# Verklaring beëindiging inschrijving bij afstuderen ['Je kunt een verklaring beëindiging inschrijving bij afstuderen op twee manieren aanvragen:  Vul het Aanvraagformulier verklaring in en ontvang de verklaring per post of e-mail. Haal de verklaring persoonlijk op bij de Centrale Studenten Administratie.', ['https://www.rug.nl/education/contact/information-services/application-form-statements', 'https://www.rug.nl/csa']]
#
# Bewijs betaald collegegeld (BBC) voor andere instelling ['Een Bewijs Betaald Collegegeld (BBC) is een bewijsstuk waaruit blijkt dat je het wettelijk collegegeld hebt betaald. Dit bewijsstuk heb je nodig als je, naast de Rijksuniversiteit Groningen, ook ingeschreven wilt staan bij een andere instelling in het hoger onderwijs.  Je kunt een BBC op twee manieren aanvragen:  Vul het Aanvraagformulier verklaring in en ontvang de BBC per post. Haal de BBC persoonlijk op bij de Centrale Studenten Administratie.  Je krijgt alleen een BBC als je officieel staat ingeschreven. Dit houdt o.a. in dat je het verschuldigde collegegeld hebt betaald of dat je machtigingsformulier is verwerkt.', ['https://www.rug.nl/education/contact/information-services/application-form-statements', 'https://www.rug.nl/csa']]
#
# Tekenen en stempelen van verklaringen voor instanties ['Je kunt verklaringen voor andere instanties laten tekenen en stempelen bij de Centrale Studenten Administratie.', ['https://www.rug.nl/csa']]
#
# Aanvragen verklaring (door organisatie) ['Vanwege de nieuwe privacywet kan alleen de (oud) student zelf een verificatieverzoek indienen. Dit kan op twee manieren:   De (oud) student kan via het diplomaregister van DUO kosteloos een uitstreksel van zijn of haar diploma te downloaden.  Een digitaal uittreksel van diplomagegevens uit het diplomaregister heeft dezelfde waarde als een papieren gewaarmerkte kopie.   De (oud) student kan via het Aanvraagformulier verklaringen een verklaring aanvragen.     ', ['http://www.duo.nl/particulieren/diplomas/over-mijn-diploma/uittreksel-diplomagegevens-downloaden.asp', 'https://www.rug.nl/education/contact/information-services/application-form-statements']]
#
# Onderwijs- en examenregelingen (OER) ['In de Onderwijs- en Examenregeling (OER) zijn de rechten en plichten van een student over allerlei zaken vastgelegd, zoals opbouw van de opleiding, toelatingseisen tot een bepaald jaar van de opleiding, de volgorde van studieonderdelen, de practica, de vorm van tentamens en studiebegeleiding.  Een overzicht van de Onderwijs- en Examenregelingen vind je op de pagina Onderwijs- en examenregelingen per faculteit op onze website.', ['https://www.rug.nl/about-us/organization/rules-and-regulations/onderwijs/onderwijs-en-examenregelingen/']]
#
# Profileringsfondsregeling ['In deze regeling zijn de regels opgenomen voor het aanvragen van financiële ondersteuning bij studievertraging door overmacht, deelname aan medezeggenschaps- en bestuursfunctie, en bij het beoefen van topsport.   Meer informatie vind je op de pagina Regeling Profileringsfonds op onze website.', ['https://www.rug.nl/about-us/organization/rules-and-regulations/onderwijs/graduation-fund-regulations']]
#
# Regeling Inschrijving en Collegegeld (RIC) ['In de Regeling Inschrijving en Collegegeld zijn de (wettelijke) bepalingen voor de inschrijving en het collegegeld aan de Rijksuniversiteit Groningen opgenomen.   Meer informatie vind je op de pagina Regeling Inschrijving en Collegegeld op onze website.', ['https://www.rug.nl/about-us/organization/rules-and-regulations/algemeen/regeling-inschrijving-collegegeld']]
#
# Studentenstatuut ['In het studentenstatuut zijn de rechten en plichten van zowel studenten als de Rijksuniversiteit Groningen vastgelegd.  Meer informatie vind je op de pagina Studentenstatuut op onze website.', ['https://www.rug.nl/about-us/organization/rules-and-regulations/onderwijs/studentenstatuut/']]
#
# Handboek Bindend Studieadvies (BSA) ['In het handboek is de regelgeving die betrekking heeft op de uitvoering van het BSA opgenomen.   Meer informatie vind je op de pagina Handboek Bindend Studieadvies (BSA) op onze website.', ['https://www.rug.nl/about-us/organization/rules-and-regulations/onderwijs/handboek-bsa']]
#
# Meer informatie regelingen ... ['Een overzicht van alle regelingen van de Rijksuniversiteit Groningen vind je op de pagina Wet- en regelgeving op onze website.', ['https://www.rug.nl/about-us/organization/rules-and-regulations/']]
#
# Handleidingen Studielink ['Er zijn verschillende handleidingen die uitleggen hoe je Studielink gebruikt.   Een overzicht van deze handleidingen vind je op de pagina Stappenplan Studielink op de website van Studielink.', ['http://info.studielink.nl/nl/studenten/stappenplanstudielink/Pages/Default.aspx']]
#
# Handleidingen OAS ['Er zijn verschillende handleidingen over het Online Application System (OAS) van de Rijksuniversiteit Groningen.   Een overzicht van deze handleidingen vind je op de pagina Instruction manuals: overview op onze website.', ['https://www.rug.nl/education/international-students/application-procedure/support/instruction-manuals_-overview']]
#
# Handleiding foto RUGpas uploaden ['In de handleiding Foto uploaden en bewijs van inschrijving downloaden staat hoe je een foto voor je RUGpas kunt uploaden.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/verklaring-inschrijving']]
#
# Handleiding verklaring van inschrijving downloaden ['In de handleiding Foto uploaden en bewijs van inschrijving downloaden staat hoe je een verkaring van inschrijving kunt downloaden.', ['https://www.rug.nl/education/bachelor/nederlandse-studenten/aanmelding-en-inschrijving/verklaring-inschrijving']]
